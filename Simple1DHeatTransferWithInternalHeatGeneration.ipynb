# %% [markdown]
# <a href="https://colab.research.google.com/github/arvindnswamy/BoundaryLayers/blob/master/Simple1DHeatTransferWithInternalHeatGeneration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sci
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

eps = 0.1
def odetobesolved(t, y):
    #when mwedge = 0, you should get bacj the results of the flat plate solution
    #return np.vstack((y[1], -y[1]-(1/eps)*(np.exp(y[0])-t-2))) 
    return np.vstack((y[1], -1*y[0]**0)) 

def odebc(ya, yb):
    return np.array([ya[1], yb[1]+0.5*yb[0]])

from scipy.integrate import solve_bvp
n = 25
x = np.linspace(0, 1, n)
y = np.array([x, x]) #initial guess

sol = solve_bvp(odetobesolved, odebc, x, y)

if sol.status != 0:
    print("WARNING: sol.status is %d" % sol.status)
print(sol.message)



plt.subplot(2, 1, 1)
plt.plot(sol.x, sol.y[0], color='#801010', label='$y_0(x)$')
plt.grid(alpha=0.5)
plt.legend(framealpha=1, shadow=True)
plt.subplot(2, 1, 2)
plt.plot(sol.x, sol.y[1], '-', color='C0', label='$y_1(x)$')
plt.xlabel('$x$')
plt.grid(alpha=0.5)
plt.legend(framealpha=1, shadow=True)
plt.show()
# Out:
# The algorithm converged to the desired accuracy.
